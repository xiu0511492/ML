# %% [markdown]
# ## This notebook illustrates Dash Python

# %%
import pandas as pd
import wget
# # url = "https://drive.google.com/uc?export=download&id=1-6Tdf9uu8nfz6bChSwTvjpse2pifeJ3t"
# #output_path = '/content/drive/MyDrive/Colab_Notebooks/linear_regression/Salary_Data.csv'   # on colab
# https://raw.githubusercontent.com/GrandmaCan/ML/main/Resgression/Salary_Data2.csv
url = "https://raw.githubusercontent.com/GrandmaCan/ML/main/Resgression/Salary_Data2.csv"   # from ref. 
output_path = './Salary_Data2.csv'
wget.download(url, out=output_path)
path = output_path
df = pd.read_csv(output_path)

display(df)
# Out:
#     YearsExperience EducationLevel City  Salary
# 0               3.0             大學  城市A    45.9
# 1               7.8           碩士以上  城市C    80.5
# 2               2.3           高中以下  城市A    25.2
# 3               5.1           高中以下  城市A    30.4
# 4              10.0           碩士以上  城市B    65.7
# 5               1.2           碩士以上  城市C    60.8
# 6               8.6             大學  城市C    50.1
# 7               6.9           碩士以上  城市A    70.3
# 8               4.2             大學  城市A    40.7
# 9               2.4           高中以下  城市A    28.1
# 10              5.3           高中以下  城市A    32.0
# 11              3.9             大學  城市A    48.3
# 12              7.2           碩士以上  城市C    84.2
# 13             10.0           碩士以上  城市B    70.9
# 14              1.5           碩士以上  城市C    62.4
# 15              8.4             大學  城市C    55.6
# 16              6.5           碩士以上  城市A    72.7
# 17              4.8             大學  城市A    42.9
# 18              2.1           高中以下  城市A    26.5
# ...

# %%
# !pip install dash
from dash import Dash, dcc, html, Input, Output
import plotly.express as px

app = Dash(__name__)


app.layout = html.Div([
    html.H4('Interactive scatter plot with dataset'),
    dcc.Graph(id="scatter-plot"),
    html.P("Filter by YearsExperience:"),
    dcc.RangeSlider(
        id='range-slider',
        min=0, max=15, step=0.2,
        marks={0: '0', 15: '15'},
        value=[2, 12]
    ),
])

df = pd.read_csv(output_path)

@app.callback(
    Output("scatter-plot", "figure"), 
    Input("range-slider", "value"))
def update_bar_chart(slider_range):
#     df = px.data.iris() # replace with your own data source
    
    low, high = slider_range
    mask = (df['YearsExperience'] > low) & (df['YearsExperience'] < high)
    fig = px.scatter(
        df[mask], x="YearsExperience", y="Salary", 
        color="City", size='Salary', 
        hover_data=['EducationLevel'])
    return fig
    
# app.run_server(debug=True)
app.run_server(debug=True, port=8052)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8052/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# !pip install dash
from dash import Dash, dcc, html, Input, Output
import plotly.express as px

app = Dash(__name__)


app.layout = html.Div([
    html.H4('Interactive scatter plot with Iris dataset'),
    dcc.Graph(id="scatter-plot"),
    html.P("Filter by petal width:"),
    dcc.RangeSlider(
        id='range-slider',
        min=0, max=2.5, step=0.1,
        marks={0: '0', 2.5: '2.5'},
        value=[0.5, 2]
    ),
])

@app.callback(
    Output("scatter-plot", "figure"), 
    Input("range-slider", "value"))
def update_bar_chart(slider_range):
    df = px.data.iris() # replace with your own data source
    low, high = slider_range
    mask = (df['petal_width'] > low) & (df['petal_width'] < high)
#     mask = (df['EducationLevel'] > low) & (df['City'] < high)
    fig = px.scatter(
        df[mask], x="sepal_width", y="sepal_length", 
        color="species", size='petal_length', 
        hover_data=['petal_width'])
    return fig
    
# app.run_server(debug=True)
app.run_server(debug=True, port=8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # 建立服務
#
# 若設置的port=8051
#
# Dash伺服器在本地主機上運行UI http://localhost:8051/
#
# 其他裝置可以使用位址來訪問您的Dash應用程式  http://your_local_ip:8051/
